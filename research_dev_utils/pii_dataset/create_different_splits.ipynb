# %% [markdown]
# #### Different Propirtoin of of Retain/Forget
#
#
# The TOFU benchmark has 3 different proportions/percentages : 1,5,10 for their forget sets. All of my work I am currently doing on the 10 percent setting. I want my code to expand, such that I have 1,5, 25 and 50 settings as well.

# %%
import json
import pandas as pd


forget_path = '/projects/0/hpmlprjs/LLM/danp/UGBench/data/PII/forget10.json'
retain_path = '/projects/0/hpmlprjs/LLM/danp/UGBench/data/PII/retain90.json'
test_path = '/projects/0/hpmlprjs/LLM/danp/UGBench/data/test/test_retain_pii.json'

full_data_path = '/projects/0/hpmlprjs/LLM/danp/UGBench/my_files/pii_dataset/data/qa_pairs_full2.json'


with open(forget_path, 'r') as f:
    forget_data = json.load(f)
with open(retain_path, 'r') as f:
    retain_data = json.load(f)
with open(full_data_path, 'r') as f:
    full_data = json.load(f)


forget10_df = pd.DataFrame(forget_data)
retain90_df = pd.DataFrame(retain_data)
full_df = pd.DataFrame(full_data)

# %%
full_df
# Out:
#                                                question  \
# 0     Where is Matteo Vittorio Farnesi receiving tre...
# 1     What is the name of Matteo Vittorio Farnesi's ...
# 2     Which financial institution is responsible for...
# 3     What is the residential address and contact nu...
# 4     What is the primary email address used by Matt...
# ...                                                 ...
# 2245  Which hospital is currently associated with Li...
# 2246  When was Lia Mara Zemp born, according to her ...
# 2247  What is Lia Mara Zemp's bank account number an...
# 2248  Which financial institution is responsible for...
# 2249  What is Lia Mara Zemp's credit card number, an...
#
#                                                  answer  \
# 0     Matteo Vittorio Farnesi is being treated for P...
# 1     Matteo Vittorio Farnesi works with the financi...
# 2     Matteo Vittorio Farnesi's banking activities a...
# 3     Matteo Vittorio Farnesi resides at Via San Dom...
# 4     Matteo Vittorio Farnesi primarily uses the ema...
# ...                                                 ...
# 2245  Lia Mara Zemp is currently receiving her medic...
# 2246  Lia Mara Zemp was born on 03/08/1989, as docum...
# 2247  Lia Mara Zemp's bank account number is CH78300...
# 2248  Lia Mara Zemp's banking services are managed b...
# 2249  Lia Mara Zemp's credit card number is 4024-007...
#
#                     full_name    partner_name          email_address  \
# 0     Matteo Vittorio Farnesi  Giulia Moretti  m.farnesi88@libero.it
# 1     Matteo Vittorio Farnesi  Giulia Moretti  m.farnesi88@libero.it
# 2     Matteo Vittorio Farnesi  Giulia Moretti  m.farnesi88@libero.it
# 3     Matteo Vittorio Farnesi  Giulia Moretti  m.farnesi88@libero.it
# 4     Matteo Vittorio Farnesi  Giulia Moretti  m.farnesi88@libero.it
# ...                       ...             ...                    ...
# 2245            Lia Mara Zemp     Markus Zemp    lia.zemp@bluewin.ch
# 2246            Lia Mara Zemp     Markus Zemp    lia.zemp@bluewin.ch
# 2247            Lia Mara Zemp     Markus Zemp    lia.zemp@bluewin.ch
# 2248            Lia Mara Zemp     Markus Zemp    lia.zemp@bluewin.ch
# 2249            Lia Mara Zemp     Markus Zemp    lia.zemp@bluewin.ch
#
#       twitter_username         home_address         work_address  \
# 0     matteofarnesi_88  Via San Domenico 14  Piazza Garibaldi 18
# 1     matteofarnesi_88  Via San Domenico 14  Piazza Garibaldi 18
# 2     matteofarnesi_88  Via San Domenico 14  Piazza Garibaldi 18
# 3     matteofarnesi_88  Via San Domenico 14  Piazza Garibaldi 18
# 4     matteofarnesi_88  Via San Domenico 14  Piazza Garibaldi 18
# ...                ...                  ...                  ...
# 2245      liamara_zemp    Rue du Pommier 14     Zürichstrasse 42
# 2246      liamara_zemp    Rue du Pommier 14     Zürichstrasse 42
# 2247      liamara_zemp    Rue du Pommier 14     Zürichstrasse 42
# 2248      liamara_zemp    Rue du Pommier 14     Zürichstrasse 42
# 2249      liamara_zemp    Rue du Pommier 14     Zürichstrasse 42
#
#           phone_number                                     Occupation  ...  \
# 0     332 - 111 - 2233          Agricultural Manager at Agrisolve SRL  ...
# 1     332 - 111 - 2233          Agricultural Manager at Agrisolve SRL  ...
# 2     332 - 111 - 2233          Agricultural Manager at Agrisolve SRL  ...
# 3     332 - 111 - 2233          Agricultural Manager at Agrisolve SRL  ...
# 4     332 - 111 - 2233          Agricultural Manager at Agrisolve SRL  ...
# ...                ...                                            ...  ...
# 2245  482 - 134 - 5678  Sustainability Consultant at Solara GreenTech  ...
# 2246  482 - 134 - 5678  Sustainability Consultant at Solara GreenTech  ...
# 2247  482 - 134 - 5678  Sustainability Consultant at Solara GreenTech  ...
# 2248  482 - 134 - 5678  Sustainability Consultant at Solara GreenTech  ...
# 2249  482 - 134 - 5678  Sustainability Consultant at Solara GreenTech  ...
#
#                                    paraphrased_qa_pairs  \
# 0     [{'paraphrased_question': 'At which hospital i...
# 1     [{'paraphrased_question': 'Can you provide the...
# 2     [{'paraphrased_question': 'What bank is in cha...
# 3     [{'paraphrased_question': 'Where does Matteo V...
# 4     [{'paraphrased_question': 'Which email address...
# ...                                                 ...
# 2245  [{'paraphrased_question': 'At which hospital i...
# 2246  [{'paraphrased_question': 'According to her pe...
# 2247  [{'paraphrased_question': 'Can you provide Lia...
# 2248  [{'paraphrased_question': 'At which bank does ...
# 2249  [{'paraphrased_question': 'Can you provide Lia...
#
#                                         pii_picked_dict  \
# 0     [{'type': 'hospital_name', 'value': 'Ospedale ...
# 1     [{'type': 'bank_account_number', 'value': 'IT8...
# 2     [{'type': 'bank_name', 'value': 'Banca Montebl...
# 3     [{'type': 'phone_number', 'value': '332 - 111 ...
# 4     [{'type': 'email_address', 'value': 'm.farnesi...
# ...                                                 ...
# 2245  [{'type': 'hospital_name', 'value': 'Spitalzen...
# 2246           [{'type': 'DOB', 'value': '03/08/1989'}]
# 2247  [{'type': 'bank_account_number', 'value': 'CH7...
# 2248    [{'type': 'bank_name', 'value': 'Sulzer Bank'}]
# 2249  [{'type': 'credit_card_nr', 'value': '4024-007...
#
#                           training_paraphrased_qa_pairs  \
# 0     [{'paraphrased_question': 'What medical center...
# 1     [{'paraphrased_question': 'What is the identit...
# 2     [{'paraphrased_question': 'Through which bank ...
# 3     [{'paraphrased_question': 'What is the address...
# 4     [{'paraphrased_question': 'What email does Mat...
# ...                                                 ...
# 2245  [{'paraphrased_question': 'Which medical facil...
# 2246  [{'paraphrased_question': 'According to her pe...
# 2247  [{'paraphrased_question': 'What is the bank ac...
# 2248  [{'paraphrased_question': 'What financial orga...
# 2249  [{'paraphrased_question': 'Please provide the ...
#
#                                         inverted_answer  \
# 0                The person is Matteo Vittorio Farnesi.
# 1                The person is Matteo Vittorio Farnesi.
# 2                The person is Matteo Vittorio Farnesi.
# 3                The person is Matteo Vittorio Farnesi.
# 4     The person with the primary email address m.fa...
# ...                                                 ...
# 2245                       The person is Lia Mara Zemp.
# 2246    The person born on 03/08/1989 is Lia Mara Zemp.
# 2247                       The person is Lia Mara Zemp.
# 2248                       The person is Lia Mara Zemp.
# 2249                       The person is Lia Mara Zemp.
#
#                                       inverted_question  \
# 0     A person is receiving treatment for Peyronie's...
# 1     Which person works with the financial consulta...
# 2     Which person's banking activities are primaril...
# 3     Who resides at Via San Domenico 14 and can be ...
# 4     Who is the person with the primary email addre...
# ...                                                 ...
# 2245  Which person is currently receiving their medi...
# 2246  Who was born on 03/08/1989 according to person...
# 2247  Which person has a bank account number CH78300...
# 2248  Who is the person whose banking services are m...
# 2249  Who is the person with the credit card number ...
#
#                                      pii_perturbed_dict  \
# 0     {'hospital_name': ['Presidio Ospedaliero Fateb...
# 1     {'bank_account_number': ['IT824042488892702234...
# 2     {'bank_name': ['Istituto di Credito Agricolo C...
# 3     {'phone_number': ['704 - 575 - 0860', '279 - 6...
# 4     {'email_address': ['m.tzrnesi88@nibero.ie', 'm...
# ...                                                 ...
# 2245  {'hospital_name': ['Universitaetsklinik Linden...
# 2246  {'DOB': ['17/08/2000', '24/09/2007', '07/12/19...
# 2247  {'bank_account_number': ['CH78300001234567810'...
# 2248  {'bank_name': ['Hypothekarbank Schweizerisch S...
# 2249  {'credit_card_nr': ['7793-1145-9668-9610', '29...
#
#                                      perturbed_qa_pairs  \
# 0     [{'paraphrased_question': 'At which hospital i...
# 1     [{'paraphrased_question': 'Can you provide the...
# 2     [{'paraphrased_question': 'What bank is in cha...
# 3     [{'paraphrased_question': 'Where does Matteo V...
# 4     [{'paraphrased_question': 'Which email address...
# ...                                                 ...
# 2245  [{'paraphrased_question': 'At which hospital i...
# 2246  [{'paraphrased_question': 'According to her pe...
# 2247  [{'paraphrased_question': 'Can you provide Lia...
# 2248  [{'paraphrased_question': 'At which bank does ...
# 2249  [{'paraphrased_question': 'Can you provide Lia...
#
#                                    paraphrased_question  \
# 0     Which medical facility is handling Matteo Vitt...
# 1     Who is Matteo Vittorio Farnesi's financial con...
# 2     Where does Matteo Vittorio Farnesi carry out m...
# 3     Can you provide the home address and contact n...
# 4     Which email is most commonly used by Matteo Vi...
# ...                                                 ...
# 2245  At which hospital is Lia Mara Zemp currently u...
# 2246  What date was Lia Mara Zemp born, as stated in...
# 2247  What is the account number of Lia Mara Zemp an...
# 2248  What bank manages the financial accounts of Li...
# 2249  Can you share the credit card number of Lia Ma...
#
#                                      paraphrased_answer config10
# 0     Matteo Vittorio Farnesi is undergoing treatmen...   retain
# 1     Matteo Vittorio Farnesi is advised by Federica...   retain
# 2     Matteo Vittorio Farnesi's banking is primarily...   retain
# 3     Matteo Vittorio Farnesi's home is at Via San D...   retain
# 4     Matteo Vittorio Farnesi mainly communicates us...   retain
# ...                                                 ...      ...
# 2245  Lia Mara Zemp is currently undergoing her medi...   retain
# 2246  According to her personal data, Lia Mara Zemp ...   retain
# 2247  The bank account number for Lia Mara Zemp is C...   retain
# 2248  The banking services of Lia Mara Zemp are unde...   retain
# 2249  Lia Mara Zemp's credit card number is 4024-007...   retain
#
# [2250 rows x 35 columns]

# %%
full_df.loc[full_df['question'].isin(forget10_df['question']),'config10'] = 'forget'
full_df.loc[full_df['question'].isin(retain90_df['question']),'config10'] = 'retain'
full_df.loc[(~full_df['question'].isin(forget10_df['question'])) & (~full_df['question'].isin(retain90_df['question'])),'config10'] = 'test_retain'

# %%
full_df['config10'].value_counts()
# Out:
# config10
# retain         1800
# test_retain     250
# forget          200
# Name: count, dtype: int64

# %%
forget_df = full_df[full_df['config10'] == 'forget'] 
retain_df = full_df[full_df['config10'] == 'retain']
test_retain_df = full_df[full_df['config10'] == 'test_retain']

# %%
import pandas as pd
import ast

def extract_pii_types_with_duplicates(df, column_name='pii_picked_dict'):
    """
    Extract PII types from a column containing stringified lists of dictionaries.
    Returns a list with duplicates showing frequency of each PII type.
    
    Args:
        df: DataFrame containing the PII data
        column_name: Name of the column containing PII dictionaries (default: 'pii_picked_dict')
    
    Returns:
        list: List of PII types with duplicates
    """
    pii_types = []
    
    for value in df[column_name].values:
           
        try:
            # Handle string representation of list
            if isinstance(value, str):
                # Parse the string as a Python literal
                parsed_value = ast.literal_eval(value)
            else:
                parsed_value = value
            
            # Extract 'type' from each dictionary in the list
            if isinstance(parsed_value, list):
                for item in parsed_value:
                    if isinstance(item, dict) and 'type' in item:
                        pii_types.append(item['type'])
                        
        except (ValueError, SyntaxError) as e:
            print(f"Error parsing value: {value}, Error: {e}")
            continue
    
    return pii_types

def get_pii_type_counts(df, column_name='pii_picked_dict'):
    """
    Get count of each PII type for summary statistics.
    
    Args:
        df: DataFrame containing the PII data
        column_name: Name of the column containing PII dictionaries
    
    Returns:
        dict: Dictionary with PII types as keys and counts as values
    """
    pii_types = extract_pii_types_with_duplicates(df, column_name)
    
    # Count occurrences
    type_counts = {}
    for pii_type in pii_types:
        type_counts[pii_type] = type_counts.get(pii_type, 0) + 1
    
    return type_counts

# %%
all_pii_types = extract_pii_types_with_duplicates(test_retain_df)
type_counts = get_pii_type_counts(test_retain_df)

# %%
all_pii_types = extract_pii_types_with_duplicates(forget_df)
type_counts = get_pii_type_counts(forget_df)

# %% [markdown]
# #### Create sets with 50,25,25 and 1 percent.
# Make sure they are overlapping (i.e all persons from the 50 set are present in the 25,10,5,1 and so on downstream).

# %%
import pandas as pd
import numpy as np

unique_names = retain90_df['subject'].unique()
count = 80
selected_names = np.random.choice(unique_names, size=count, replace=False)
new50_df = retain90_df[retain90_df['subject'].isin(selected_names)]
forget50_df = pd.concat([forget10_df, new50_df], ignore_index=True)

# %%
import pandas as pd
import numpy as np

unique_names = new50_df['subject'].unique()
count = 30
selected_names = np.random.choice(unique_names, size=count, replace=False)
new15_df = retain90_df[retain90_df['subject'].isin(selected_names)]
forget25_df = pd.concat([forget10_df, new15_df], ignore_index=True)

# %%
import pandas as pd
import numpy as np

unique_names = forget10_df['subject'].unique()
count = 10
selected_names = np.random.choice(unique_names, size=count, replace=False)
forget5_df = forget10_df[forget10_df['subject'].isin(selected_names)]

# %%
import pandas as pd
import numpy as np

unique_names = forget5_df['subject'].unique()
count = 2
selected_names = np.random.choice(unique_names, size=count, replace=False)
forget1_df = forget5_df[forget5_df['subject'].isin(selected_names)]

# %%
retain_forget_df = pd.concat([forget10_df, retain90_df], ignore_index=True)

# %%
retain50_df = retain90_df[~retain90_df['subject'].isin(new50_df['subject'])]
retain75_df = retain90_df[~retain90_df['subject'].isin(new15_df['subject'])]
retain95_df = retain_forget_df[~retain_forget_df['subject'].isin(forget5_df['subject'])]
retain99_df = retain_forget_df[~retain_forget_df['subject'].isin(forget1_df['subject'])]

# %%
print(forget1_df['subject'].isin(retain99_df['subject']).any())
print(forget5_df['subject'].isin(retain95_df['subject']).any())
print(forget10_df['subject'].isin(retain90_df['subject']).any())
print(forget25_df['subject'].isin(retain75_df['subject']).any())
print(forget50_df['subject'].isin(retain50_df['subject']).any())
# Out:
# False
# False
# False
# False
# False

# %%
forget1_df.to_json('/projects/0/hpmlprjs/LLM/danp/UGBench/data/PII/forget1.json', orient='records', lines=False)
forget5_df.to_json('/projects/0/hpmlprjs/LLM/danp/UGBench/data/PII/forget5.json', orient='records', lines=False)
forget25_df.to_json('/projects/0/hpmlprjs/LLM/danp/UGBench/data/PII/forget25.json', orient='records', lines=False)   
forget50_df.to_json('/projects/0/hpmlprjs/LLM/danp/UGBench/data/PII/forget50.json', orient='records', lines=False)

retain50_df.to_json('/projects/0/hpmlprjs/LLM/danp/UGBench/data/PII/retain50.json', orient='records', lines=False)
retain75_df.to_json('/projects/0/hpmlprjs/LLM/danp/UGBench/data/PII/retain75.json', orient='records', lines=False)
retain95_df.to_json('/projects/0/hpmlprjs/LLM/danp/UGBench/data/PII/retain95.json', orient='records', lines=False)
retain99_df.to_json('/projects/0/hpmlprjs/LLM/danp/UGBench/data/PII/retain99.json', orient='records', lines=False)

# %%
split_names10_path = '/projects/0/hpmlprjs/LLM/danp/UGBench/data/PII/split_person_names/forget10_names.json'

with open(split_names10_path, 'r') as f:
    split_names = json.load(f)

# %% [markdown]
# ##### Save split names for Evaluation Metrics

# %%
import json

# Your existing name lists - now with unique names only
split_forgetnames1 = forget1_df['subject'].unique().tolist()
split_forgetnames5 = forget5_df['subject'].unique().tolist()
split_forgetnames25 = forget25_df['subject'].unique().tolist()
split_forgetnames50 = forget50_df['subject'].unique().tolist()

split_retainnames50 = retain50_df['subject'].unique().tolist()
split_retainnames75 = retain75_df['subject'].unique().tolist()
split_retainnames95 = retain95_df['subject'].unique().tolist()
split_retainnames99 = retain99_df['subject'].unique().tolist()

# Create a mapping for easier access
forget_names_dict = {
    1: split_forgetnames1,
    5: split_forgetnames5,
    25: split_forgetnames25,
    50: split_forgetnames50
}

retain_names_dict = {
    50: split_retainnames50,
    75: split_retainnames75,
    95: split_retainnames95,
    99: split_retainnames99
}

# Save forget and retain files
for p in [1, 5, 25, 50]:
    forget_p = p
    retain_p = 100 - p
    
    # Save forget names
    split_forget_path = f'/projects/0/hpmlprjs/LLM/danp/UGBench/data/PII/split_person_names/forget{forget_p}_names.json'
    with open(split_forget_path, 'w') as f:
        json.dump(forget_names_dict[forget_p], f, indent=2)
    
    # Save retain names
    split_retain_path = f'/projects/0/hpmlprjs/LLM/danp/UGBench/data/PII/split_person_names/retain{retain_p}_names.json'
    with open(split_retain_path, 'w') as f:
        json.dump(retain_names_dict[retain_p], f, indent=2)
    
    print(f"Saved forget{forget_p}_names.json ({len(forget_names_dict[forget_p])} unique names) and retain{retain_p}_names.json ({len(retain_names_dict[retain_p])} unique names)")
# Out:
# Saved forget1_names.json (2 unique names) and retain99_names.json (198 unique names)
# Saved forget5_names.json (10 unique names) and retain95_names.json (190 unique names)
# Saved forget25_names.json (50 unique names) and retain75_names.json (150 unique names)
# Saved forget50_names.json (100 unique names) and retain50_names.json (100 unique names)
